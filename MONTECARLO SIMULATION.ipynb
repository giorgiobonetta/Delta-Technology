# %% [markdown]
# <a href="https://colab.research.google.com/github/giorgiobonetta/Delta-Technology/blob/main/MONTECARLO%20SIMULATION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# MONTECARLO SIMULATION

# %%
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt

df = yf.download('TSLA')

returns= np.log(1+df['Adj Close'].pct_change())
mu, sigma=returns.mean(), returns.std()
sim_rets=np.random.normal(mu,sigma, 252)
initial=df['Adj Close'].iloc[-1]
simulated_prices=initial*(sim_rets + 1).cumprod()
plt.plot(simulated_prices)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
for i in range(100):
  sim_rets=np.random.normal(mu,sigma,252)
  simulated_prices=initial*(sim_rets+1).cumprod()
  plt.axhline(initial, c='k')
  plt.plot(simulated_prices)
